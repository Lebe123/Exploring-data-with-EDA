# %% [markdown]
# # Exploratory Data Analysis(EDA) Using Python Project
# Exploratory data analysis one of the most important techiniques for a data scientists. EDA is all about understanding data sets by summarizing their main characteristics often plotting them visually.
# Plotting in EDA consists of histohrams, box plot, scatter plot.
# Through the process of EDA, we can ask to define the problem statement or definition on our data set which is very important.
# The data set used for this EDA project cars from Kaggle.

# %% [markdown]
# #### 1. Importing the required libraries for EDA
# Below are the libraries that are used in order to perform basic EDA.

# %%
# Importing required libraries.
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline  
sns.set(color_codes=True)

# %% [markdown]
# #### 2. Loading the data into the data frame
# Loading the data into the pandas data frame is certainly one of the most important steps in EDA.

# %%
df=pd.read_csv('data.csv')
# Display the top 5 rows
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
# display the bottom 5 rows
df.tail()
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %% [markdown]
# #### 3. Checking the data type
# Checking for datatypes is always important because some datatypes expected to be variable/float or integer might be stored as string or object. The MSRP or the price of the car would be stored as a string or object, if in that case, we have to convert that string to the integer data only then we can plot the data via a graph. The data is already in integer format so nothing to worry in this particular example.

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
#run basic descriptive stats on variable da
df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# #### 4. Dropping irrelevant columns
# This step is certainly needed in every EDA because sometimes there would be many columns that we never use in such cases dropping is the only solution. In this case, the columns such as Engine Fuel Type, Market Category, Vehicle style, Popularity, Number of doors, vehicle Size doesn't make any sense to me. Dropping in this case makes sense.

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
df=df.drop(['Engine Fuel Type','Market Category','Vehicle Style','Popularity','Number of Doors','Vehicle Size'],axis=1)
df.head()
# Out:
#   Make       Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011      335.0               6.0            MANUAL
# 1  BMW    1 Series  2011      300.0               6.0            MANUAL
# 2  BMW    1 Series  2011      300.0               6.0            MANUAL
# 3  BMW    1 Series  2011      230.0               6.0            MANUAL
# 4  BMW    1 Series  2011      230.0               6.0            MANUAL
#
#       Driven_Wheels  highway MPG  city mpg   MSRP
# 0  rear wheel drive           26        19  46135
# 1  rear wheel drive           28        19  40650
# 2  rear wheel drive           28        20  36350
# 3  rear wheel drive           28        18  29450
# 4  rear wheel drive           28        18  34500

# %% [markdown]
# #### 5. Renaming the columns
# In this instance, most of the column names are very confusing to read, so I just tweaked their column names. This is a good approach, it improves the readability of the data set.

# %%
df=df.rename(columns={'Engine HP':'HP','Engine Cylinders':'Cylinders',
                      'Transmission Type':'Transmission','Driven_Wheels':'Drive Mode',
                      'highway MPG':'MPG-H','city mpg':'MPG-C','MSRP':'Price'})
df.head()
# Out:
#   Make       Model  Year     HP  Cylinders Transmission        Drive Mode  \
# 0  BMW  1 Series M  2011  335.0        6.0       MANUAL  rear wheel drive
# 1  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# 2  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# 3  BMW    1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
# 4  BMW    1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
#
#    MPG-H  MPG-C  Price
# 0     26     19  46135
# 1     28     19  40650
# 2     28     20  36350
# 3     28     18  29450
# 4     28     18  34500

# %% [markdown]
# #### 6. Dropping the duplicate rows
# This is often a handy thing ti do because a huge data set as in this case contains more than 11,000 rows often have some duplicate data which might be disturbing, so removing all the duplicate value from the data-set.

# %%
# Total number of rows and columns before removing duplicates
df.shape
# Out:
# (11914, 10)

# %%
# Rows containing duplicates data
duplicate_rows_df=df[df.duplicated()]
print('number of duplicate rows:',duplicate_rows_df.shape)
# Out:
# number of duplicate rows: (989, 10)

# %%
# check count before removing duplicated rows
df.count()
# Out:
# Make            11914
# Model           11914
# Year            11914
# HP              11845
# Cylinders       11884
# Transmission    11914
# Drive Mode      11914
# MPG-H           11914
# MPG-C           11914
# Price           11914
# dtype: int64

# %%
# dropping the duplicated rows
df=df.drop_duplicates()
df.head()
# Out:
#   Make       Model  Year     HP  Cylinders Transmission        Drive Mode  \
# 0  BMW  1 Series M  2011  335.0        6.0       MANUAL  rear wheel drive
# 1  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# 2  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# 3  BMW    1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
# 4  BMW    1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
#
#    MPG-H  MPG-C  Price
# 0     26     19  46135
# 1     28     19  40650
# 2     28     20  36350
# 3     28     18  29450
# 4     28     18  34500

# %%
# check counts after removing rows
df.count()
# Out:
# Make            10925
# Model           10925
# Year            10925
# HP              10856
# Cylinders       10895
# Transmission    10925
# Drive Mode      10925
# MPG-H           10925
# MPG-C           10925
# Price           10925
# dtype: int64

# %% [markdown]
# #### 7. Dropping the missing or null values
# This is mostly similar to the previous step but here the missing values are detected and are dropped later. The best approach is to replace the missing values with the mean or the average of the column but in this case, it is oky to drop the missing values. This is because there is nearly 100 missing value compared to 10,000 values. This is a small number and negligible.

# %%
# Check null values
print(df.isnull().sum())
# Out:
# Make             0
# Model            0
# Year             0
# HP              69
# Cylinders       30
# Transmission     0
# Drive Mode       0
# MPG-H            0
# MPG-C            0
# Price            0
# dtype: int64

# %%
# Dropping the missing values
df=df.dropna()
df.count()
# Out:
# Make            10827
# Model           10827
# Year            10827
# HP              10827
# Cylinders       10827
# Transmission    10827
# Drive Mode      10827
# MPG-H           10827
# MPG-C           10827
# Price           10827
# dtype: int64

# %%
# check null values again
print(df.isnull().sum())
# Out:
# Make            0
# Model           0
# Year            0
# HP              0
# Cylinders       0
# Transmission    0
# Drive Mode      0
# MPG-H           0
# MPG-C           0
# Price           0
# dtype: int64

# %% [markdown]
# #### 8. Detecting Outliers
# An outlier is a point or set of points that are different from other points. Sometimes they can be very high or very low. It is often a good idea to detect and remove the outliers. Because outliers are one of the primary reasons for resulting in aless accuarte model. Hence it is a good idea to remove them. The outlier detection and removing that I am going to perform is called IQR score technique. Often outliers can be seen with visualizations using box plot. Shown below are the box plot of MSRP, Cylinders, Horsepower and EngineSize.

# %%
sns.boxplot(x=df['Price'])
plt.title('Box Plot For Detecting Outliers On Price')
plt.show()

# %%
sns.boxplot(x=df['HP'])
plt.title('Box Plot for Detecting Outliers on Horse Power')
plt.show()

# %%
sns.boxplot(x=df['Cylinders'])
plt.title('Box Plot for detecting outliers on Cylinders')
plt.show()

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# Year             9.0
# HP             130.0
# Cylinders        2.0
# MPG-H            8.0
# MPG-C            6.0
# Price        21327.5
# dtype: float64

# %%
#removing the outliers
df=df[~((df<(Q1-1.5*IQR))|(df>(Q3+IQR*1.5))).any(axis=1)]
df.shape
# Out:
# (9191, 10)

# %% [markdown]
# #### 9. Plot different features against one another (scatter, against frequency)

# %% [markdown]
# ##### Histogram
# Histogram refers to the frequency of occurrence of variables in an interval. In this , there are mainly 10 different types of car manufacturing companies, but it is often important to know who has the most numbers of cars. To do this histogram is one of the trival solutions which lets us know the total number of car manufcatured by a different compnay.

# %%
# plotting histogram
df.Make.value_counts().nlargest(40).plot(kind='bar',figsize=(10,15))
plt.title('Number of rows by make')
plt.ylabel('Number of cars')
plt.xlabel('Make')
plt.show()

# %% [markdown]
# ##### Heat Maps
# Heat Maps is a type of plot which is necessary when we need to find the dependent variables. One of the best way to find the relationship between the features can be done using heat maps.

# %%
## finding the relations between the variables
plt.figure(figsize=(20,10))
c=df.corr()
sns.heatmap(c,cmap='BrBG',annot=True)
c
# Out:
#                Year        HP  Cylinders     MPG-H     MPG-C     Price
# Year       1.000000  0.326726  -0.133920  0.378479  0.338145  0.592983
# HP         0.326726  1.000000   0.715237 -0.443807 -0.544551  0.739042
# Cylinders -0.133920  0.715237   1.000000 -0.703856 -0.755540  0.354013
# MPG-H      0.378479 -0.443807  -0.703856  1.000000  0.939141 -0.106320
# MPG-C      0.338145 -0.544551  -0.755540  0.939141  1.000000 -0.180515
# Price      0.592983  0.739042   0.354013 -0.106320 -0.180515  1.000000

# %% [markdown]
# ##### Scatterplot
# Scatter plots are helpful to find the correlation between two variables.

# %%
# Plotting a scatter plot
fig,ax=plt.subplots(figsize=(10,6))
ax.scatter(df['HP'],df['Price'])
ax.set_xlabel('HP')
ax.set_ylabel('Price')
ax.set_title('Price vs Horse Power')
plt.show()
